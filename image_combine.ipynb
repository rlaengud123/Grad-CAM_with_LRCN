# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np
from tqdm import tqdm, trange
import glob
import os
import cv2

# %%
path = r"C:\Users\for_someday\Desktop\grad-cam-pytorch-master\results"
all_folder_list = os.listdir(r"C:\Users\for_someday\Desktop\grad-cam-pytorch-master\results")
save_path = r"C:\Users\for_someday\Desktop\grad-cam-pytorch-master\results2"

fig = plt.figure(figsize=[200,30]) # rows*cols 행렬의 i번째 subplot 생성
rows = 1
cols = 15

all_folder_list = ['13']

for k in tqdm(all_folder_list):
    folder_list = os.listdir(os.path.join(path, k))
    for j in trange(len(folder_list)):
        i = 1
        for filename in glob.glob(path + '/' + k + '/' + folder_list[j] + "/*.png"):
            img = cv2.imread(filename)
            ax = fig.add_subplot(rows, cols, i)
            ax.imshow(img)

            i += 1
        plt.savefig(save_path + '/' + k + '/' + folder_list[j] + '.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f5d309a81217> in <module>
#       3 save_path = r"C:\Users\for_someday\Desktop\grad-cam-pytorch-master\results2"
#       4
# ----> 5 fig = plt.figure(figsize=[200,30]) # rows*cols 행렬의 i번째 subplot 생성
#       6 rows = 1
#       7 cols = 15
#
# NameError: name 'plt' is not defined

# %%
path = r"C:\Users\for_someday\Desktop\grad-cam-pytorch-master\results2"
all_folder_list = os.listdir(r"C:\Users\for_someday\Desktop\grad-cam-pytorch-master\results2")
save_path = r"C:\Users\for_someday\Desktop\grad-cam-pytorch-master\results3"


fig = plt.figure(figsize=[200,30*10]) # rows*cols 행렬의 i번째 subplot 생성
rows = 10
cols = 1
count = 0
all_folder_list = ['13']

start = 0
end = 10

for k in tqdm(all_folder_list):
    folder_list = os.listdir(os.path.join(path, k))
    file_list = list(glob.glob(path + '/' + k + "/*.png"))
    while(count<=56):
        i = 1
        for j in tqdm(file_list[start:end]):
            img = cv2.imread(j)
            ax = fig.add_subplot(rows, cols, i)
            ax.set_title(j.split('/')[1], fontsize=150)
            ax.imshow(img)
            i += 1
        plt.savefig(save_path + '/' + k + '/' + str(count) +'.png')
        count += 1
        start += 10
        end += 10
# Out:
# 0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x0000026235E46048> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x0000026235E46048> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ...
